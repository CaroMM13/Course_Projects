# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ## **Objectives**
#
# - Understand the capabilities of R and its uses in Data Science.
# - Explore the RStudio interface for running R code.
# - Learn about popular R packages for Data Science.
# - Review popular data visualization packages in R.
# - Create plots using the built-in R plotting functions.
# - Create plotssing **plot2**.h ggplot.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. SQL
# 3. R

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. pandas
# 2. numpy
# 3. matplotlib

# %% [markdown]
# Here is de Data Science Tools Table:
#
# | Data Science Tools |
# | -------------|
# | Jupyter Notebook |
# | R Studio |
# | VS Code |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python:

# %%
(3*4) + 5 # This a simple arithmetic expression to multiply then add integers.
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60.
resultado = (200 / 60)
print(resultado)


#def minutos_a_horas(minutos):
#    "This will convert 200 minutes to hours by diving by 60"
#    return minutos / 60
    
#minutos_a_horas(200)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Carolyn Martinez
